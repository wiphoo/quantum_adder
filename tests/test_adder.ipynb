# %%
from adder import Adder

# %%
num_bits = 4
adder = Adder()

# %%
a = '1000'
b = '0110'
adder.draw_initialize_input_circuit(a, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=232x196 at 0x7F045C583370>

# %%
adder.draw_initialize_input_circuit(b, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=232x189 at 0x7F045C5832B0>

# %%
adder.draw_qft_circuit(num_bits, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=668x196 at 0x7F04A8036130>

# %%
adder.draw_add_circuit(num_bits, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=715x283 at 0x7F04A909ED90>

# %%
adder.draw_inverse_qft_circuit(num_bits, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=668x196 at 0x7F046FD2F100>

# %%
adder.draw_adder_circuit(a, b, 'latex')
# Out:
# /home/terng/works/quantum/adder/venv/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py:876: DeprecationWarning: The QuantumCircuit.extend() method is being deprecated. Use the compose() (potentially with the inplace=True argument) and tensor() methods which are more flexible w.r.t circuit register compatibility.
#   return self.extend(rhs)
# <PIL.Image.Image image mode=RGB size=5106x506 at 0x7F04A8036610>
