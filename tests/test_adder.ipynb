# %%
from adder import Adder

# %%
num_bits = 4
adder = Adder()

# %%
a = '1000'
b = '0110'
adder.draw_initialize_input_circuit(a, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=232x196 at 0x7FE88E02C2E0>

# %%
adder.draw_initialize_input_circuit(b, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=232x189 at 0x7FE8A183DE80>

# %%
adder.draw_qft_circuit(num_bits, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=668x196 at 0x7FE88E02C220>

# %%
adder.draw_add_circuit(num_bits, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=715x288 at 0x7FE88E009F40>

# %%
adder.draw_inverse_qft_circuit(num_bits, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=668x196 at 0x7FE8D825E220>
