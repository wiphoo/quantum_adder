# %%
from adder import Adder

# %%
num_bits = 2
adder = Adder()

# %%
a = '01'
b = '01'
adder.draw_initialize_input_circuit(a, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=232x91 at 0x7FF7CB534490>

# %%
adder.draw_initialize_input_circuit(b, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=232x91 at 0x7FF7CB516FD0>

# %%
adder.draw_qft_circuit(num_bits, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=377x92 at 0x7FF7D00EC8B0>

# %%
adder.draw_add_circuit(num_bits, 'latex')
# Out:
# i=0,n=3
# i=1,n=3
# i=2,n=3
# <PIL.Image.Image image mode=RGB size=569x210 at 0x7FF7DED42F10>

# %%
adder.draw_inverse_qft_circuit(num_bits, 'latex')
# Out:
# <PIL.Image.Image image mode=RGB size=377x92 at 0x7FF816FFDD90>

# %%
adder.draw_adder_circuit(a, b, 'latex')
# Out:
# /home/terng/works/quantum/adder/venv/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py:876: DeprecationWarning: The QuantumCircuit.extend() method is being deprecated. Use the compose() (potentially with the inplace=True argument) and tensor() methods which are more flexible w.r.t circuit register compatibility.
#   return self.extend(rhs)
# i=0,n=3
# i=1,n=3
# i=2,n=3
# i=0,n=2
# i=1,n=2
# i=0,n=1
# <PIL.Image.Image image mode=RGB size=1999x298 at 0x7FF7DECE5F10>

# %%
(quantum_circuit, output_register) = adder.create_adder_circuit(a, b)
quantum_circuit += adder.create_measure_circuit(output_register)
# Out:
# i=0,n=3
# i=1,n=3
# i=2,n=3
# i=0,n=2
# i=1,n=2
# i=0,n=1

# %%
quantum_circuit.draw('latex')
# Out:
# <PIL.Image.Image image mode=RGB size=2209x380 at 0x7FF8147989A0>

# %% [markdown]
# # run an experiment on IBM Q

# %%
import qiskit

# %%
backend = qiskit.BasicAer.get_backend( 'qasm_simulator' )
result = qiskit.execute( quantum_circuit, backend ).result()
print(f'a={a}, b={b}')
print(f'result={result.get_counts()}')
# Out:
# a=01, b=01
# result={'011': 105, '000': 239, '010': 255, '110': 136, '001': 216, '100': 34, '101': 39}
